# %%
# find out min(),max() of array columnwise, rowwise
# Differnce between ravel & flattern?

import numpy as np

# %%
b = np.array([[23,10,34,78]])

# %%
b
# Out:
# array([[23, 10, 34, 78]])

# %%
b.min()
# Out:
# 10

# %%
b.max()
# Out:
# 78

# %%
a = np.array([[1,2,3],[4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 6

# %%
# Row wise min value
a.min(axis=1)
# Out:
# array([1, 4])

# %%
# Column wise value

a.max(axis=0)
# Out:
# array([4, 5, 6])

# %%
# The flatten() function returns a copy of the array, while the ravel() function
# returns a view of the original array whenever possible
