# %%
# np.substract()
# np.divide()
# np.multiply()
#np.power()
#np.floor_divide()
#np.mod()

# %%
import numpy as np

# %%
a = np.array([[34,89],[23,67]])

# %%
a
# Out:
# array([[34, 89],
#        [23, 67]])

# %%
z = np.array([[23,10],[2,58]])

# %%
z
# Out:
# array([[23, 10],
#        [ 2, 58]])

# %%
np.subtract(a,z)
# Out:
# array([[11, 79],
#        [21,  9]])

# %%
np.multiply(a,z)
# Out:
# array([[ 782,  890],
#        [  46, 3886]])

# %%
np.divide(a,z)
# Out:
# array([[ 1.47826087,  8.9       ],
#        [11.5       ,  1.15517241]])

# %%
np.mod(a,z)
# Out:
# array([[11,  9],
#        [ 1,  9]])

# %%
np.power(a,2)
# Out:
# array([[1156, 7921],
#        [ 529, 4489]])

# %%
np.floor_divide(a,z)
# Out:
# array([[ 1,  8],
#        [11,  1]])
