# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t = sns.load_dataset('titanic')
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
t.who.describe()
# Out:
# count     891
# unique      3
# top       man
# freq      537
# Name: who, dtype: object

# %%
t['who']
# Out:
# 0        man
# 1      woman
# 2      woman
# 3      woman
# 4        man
#        ...
# 886      man
# 887    woman
# 888    woman
# 889      man
# 890      man
# Name: who, Length: 891, dtype: object

# %%
t['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
cls = t['who'].value_counts()
cls.index
# Out:
# Index(['man', 'woman', 'child'], dtype='object', name='who')

# %%
cls.values
# Out:
# array([537, 271,  83])

# %%
plt.pie(cls.values)
# Out:
# ([<matplotlib.patches.Wedge at 0x7d7cc54edf60>,
# ...
#  [Text(-0.3487593016911999, 1.0432482683828748, ''),
#   Text(0.03296249724279082, -1.0995060135240367, ''),
#   Text(1.0532306714066144, -0.3173407518872612, '')])

# %%
plt.pie(cls.values,labels=cls.index,autopct='%.2f%%',explode=[0,0.2,0])
plt.show()
